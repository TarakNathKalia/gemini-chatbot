# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, AIMessage
from dotenv import load_dotenv

load_dotenv()
gemini_key = os.getenv("GEMINI_API_KEY")
os.environ["GOOGLE_API_KEY"] = gemini_key

chat_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
chat_history = []

while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Bot: Goodbye!")
        break

    chat_history.append(HumanMessage(content=user_input))

    response = chat_model.invoke(chat_history)
    
    chat_history.append(response)

    print("Bot:", response.content)
# Out:
# You:  hii
# Bot: Hi there! How can I help you today?
# You:  what is machine learning
# Bot: Machine Learning (ML) is a branch of Artificial Intelligence (AI) that enables systems to **learn from data, identify patterns, and make decisions or predictions with minimal human intervention.**
#
# Instead of being explicitly programmed with rules for every possible scenario, a machine learning model is "trained" on a large dataset. During this training, it discovers underlying structures, relationships, and patterns within the data, which it then uses to generalize and make predictions or decisions on new, unseen data.
#
# Here's a breakdown of the core concepts:
#
# 1.  **Learning from Data:** The fundamental idea is that computers can learn from examples, just like humans do. If you want a computer to identify cats, instead of writing a rule like "if it has four legs, fur, and meows, it's a cat," you show it thousands of pictures labeled "cat" and "not cat." The ML algorithm then figures out the common characteristics of "cats" on its own.
#
# 2.  **Pattern Recognition:** ML algorithms are excellent at finding hidden patterns and correlations in vast amounts of data that would be impossible for humans to detect.
#
# 3.  **No Explicit Programming:** This is a key differentiator. In traditional programming, you write step-by-step instructions. In ML, you provide data and an algorithm, and the algorithm *learns* the rules or model itself.
#     *   **Traditional Programming:** Rules + Data = Answers
#     *   **Machine Learning:** Data + Answers = Rules (the learned model)
#
# 4.  **Generalization:** The goal isn't just to memorize the training data, but to learn patterns that allow the system to perform well on new, unseen data.
#
# ---
#
# ### How Machine Learning Works (Simplified Process):
#
# 1.  **Data Collection:** Gather relevant data (e.g., images, text, numbers).
# 2.  **Data Preparation:** Clean, format, and label the data if necessary. This is often the most time-consuming step.
# 3.  **Choose a Model/Algorithm:** Select an appropriate algorithm based on the problem (e.g., neural networks, decision trees, support vector machines).
# 4.  **Training:** Feed the prepared data into the algorithm. The algorithm adjusts its internal parameters to learn the patterns and relationships. This results in a "trained model."
# 5.  **Evaluation:** Test the trained model on a separate dataset (test set) that it hasn't seen before to assess its accuracy and performance.
# 6.  **Deployment:** Once the model performs satisfactorily, it can be integrated into applications to make real-time predictions or decisions.
#
# ---
#
# ### Main Types of Machine Learning:
#
# 1.  **Supervised Learning:**
#     *   **Concept:** The model learns from "labeled" data, meaning each input example has a corresponding correct output. It's like learning with a teacher.
#     *   **Examples:**
#         *   **Classification:** Predicting a category (e.g., spam/not spam, disease/no disease).
#         *   **Regression:** Predicting a continuous value (e.g., house prices, temperature).
#
# 2.  **Unsupervised Learning:**
#     *   **Concept:** The model learns from "unlabeled" data, trying to find hidden patterns or structures on its own without any prior knowledge of correct outputs. It's like learning without a teacher.
#     *   **Examples:**
#         *   **Clustering:** Grouping similar data points together (e.g., customer segmentation).
#         *   **Dimensionality Reduction:** Simplifying data while retaining important information.
#
# 3.  **Reinforcement Learning:**
#     *   **Concept:** The model learns by interacting with an environment, receiving rewards for desired actions and penalties for undesirable ones. It learns through trial and error to maximize its cumulative reward.
#     *   **Examples:** Game playing (e.g., AlphaGo), robotics, self-driving cars.
#
# ---
#
# ### Common Applications of Machine Learning:
#
# *   **Recommendation Systems:** (Netflix suggests movies, Amazon suggests products)
# *   **Image and Speech Recognition:** (Facial recognition, voice assistants like Siri/Alexa)
# *   **Natural Language Processing (NLP):** (Spam filters, machine translation, chatbots)
# *   **Fraud Detection:** (Identifying unusual credit card transactions)
# *   **Medical Diagnosis:** (Analyzing medical images to detect diseases)
# *   **Self-Driving Cars:** (Perceiving the environment, making driving decisions)
#
# In essence, Machine Learning is about building intelligent systems that can adapt and improve their performance over time by learning from data, making it a powerful tool for solving complex problems across virtually every industry.
# You:  exit
# Bot: Goodbye!
