# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, AIMessage
from dotenv import load_dotenv

load_dotenv()
gemini_key = os.getenv("GEMINI_API_KEY")
os.environ["GOOGLE_API_KEY"] = gemini_key

chat_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
chat_history = []

# File to save chat history
log_file = "chat_history.txt"

while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Bot: Goodbye!")
        break

    # Add user message to chat history
    chat_history.append(HumanMessage(content=user_input))

    # Get bot response
    response = chat_model.invoke(chat_history)
    chat_history.append(response)

    # Print bot response
    print("Bot:", response.content)

    # Save conversation to file
    with open(log_file, "a", encoding="utf-8") as f:
        f.write(f"You: {user_input}\n")
        f.write(f"Bot: {response.content}\n\n")
# Out:
# You:  hii
# Bot: Hi there! How can I help you today?
# You:  what is machine learning
# Bot: Machine Learning (ML) is a subfield of Artificial Intelligence (AI) that enables computer systems to **learn from data** without being explicitly programmed for every task.
#
# Think of it this way:
#
# *   **Traditional Programming:** You write specific rules and instructions for the computer to follow. If you want it to identify a cat, you'd have to write code that says, "If it has pointed ears, whiskers, and meows, it's a cat." This is hard for complex tasks.
# *   **Machine Learning:** Instead of giving the computer explicit rules, you feed it a lot of examples (data). For the cat example, you'd show it thousands of pictures, some with cats, some without, and tell it which ones are cats. The machine then *learns* to identify the patterns and features that distinguish a cat on its own.
#
# **Here's a breakdown of the core concepts:**
#
# 1.  **Learning from Data:** This is the fundamental principle. ML algorithms are trained on vast amounts of data (images, text, numbers, audio, etc.).
# 2.  **Pattern Recognition:** During training, the algorithms look for hidden patterns, relationships, and structures within that data.
# 3.  **Building a Model:** The "learning" process results in a "model." This model is essentially a set of learned rules or a statistical representation that can make predictions or decisions based on new, unseen data.
# 4.  **Generalization:** The goal is for the model to generalize well, meaning it can accurately perform its task on data it has never encountered before.
# 5.  **Iteration and Improvement:** As more data becomes available, or as performance needs to improve, the model can be retrained and refined.
#
# **Why is Machine Learning so powerful?**
#
# *   **Handles Complexity:** It excels at problems where writing explicit rules is too difficult or impossible (e.g., recognizing faces, understanding natural language).
# *   **Adapts and Improves:** It can learn and adapt over time as it's exposed to more data.
# *   **Discovers Insights:** It can uncover hidden patterns and correlations in data that humans might miss.
# *   **Automates Tasks:** It allows for the automation of tasks that require intelligence and decision-making.
#
# **Common Types of Machine Learning:**
#
# *   **Supervised Learning:** The most common type. The algorithm learns from labeled data (input-output pairs).
#     *   *Examples:* Spam detection (emails labeled as spam/not spam), image classification (images labeled as cat/dog), predicting house prices.
# *   **Unsupervised Learning:** The algorithm learns from unlabeled data, trying to find hidden structures or patterns on its own.
#     *   *Examples:* Customer segmentation (grouping customers with similar buying habits), anomaly detection (finding unusual network activity), data compression.
# *   **Reinforcement Learning:** The algorithm learns by interacting with an environment, receiving rewards for good actions and penalties for bad ones, like training a pet.
#     *   *Examples:* Game AI (AlphaGo), robotics, self-driving cars.
#
# **Real-World Examples of Machine Learning:**
#
# *   **Recommendation Systems:** "Customers who bought this also bought..." (Amazon, Netflix)
# *   **Voice Assistants:** Siri, Alexa, Google Assistant
# *   **Facial Recognition:** Unlocking your phone, tagging friends on social media
# *   **Spam Filters:** Identifying and blocking unwanted emails
# *   **Fraud Detection:** Flagging suspicious financial transactions
# *   **Medical Diagnosis:** Assisting doctors in identifying diseases from scans or patient data
# *   **Self-Driving Cars:** Interpreting sensor data to navigate roads
#
# In essence, Machine Learning is about teaching computers to learn from experience, much like humans do, enabling them to solve complex problems and make intelligent decisions.
# You:  exit
# Bot: Goodbye!
